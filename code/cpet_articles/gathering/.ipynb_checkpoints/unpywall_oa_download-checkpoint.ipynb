# %%
import requests
import pandas as pd
from unpywall.utils import UnpywallCredentials
from unpywall import Unpywall
import requests

UnpywallCredentials('hesse151@umn.edu')
# Out:
# Your email has been set.

# %%
articles = pd.read_csv('/Users/antonhesse/Desktop/Anton/Education/UMN/Lab and Research/HSPL/CPET_data_analysis/data/cpet_articles/ovid/unpaywall_info.csv')
oa_articles = articles[articles['is_oa'] == True].reset_index(drop=True)
status_code = []

for idx, row in oa_articles.iterrows():

    url = Unpywall.get_pdf_link(doi = row.doi_url)
    
    if url:
        # this just checks to make sure there's a URL before sending the request
        try:
            headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.15; rv:100.0) Gecko/20100101 Firefox/100.0'}
            response = requests.get(url, headers = headers)

            if response.status_code == 200:
                status_code.append(response.status_code)
                # save the PDF if the server responds

                # drop the doi prefix so you can use the DOI as a filename
                drop_prefix = str(row.doi.split('/')[1:]).strip('[').strip("']")
                folder_name = '/Users/antonhesse/Desktop/Anton/Education/UMN/Lab and Research/HSPL/CPET_data_analysis/data/cpet_articles/ovid/ovid_pdfs/'
                filename = folder_name + str(drop_prefix)+'.pdf'

                # write the PDF
                with open(filename, 'wb') as f:
                    f.write(response.content)

            else:
                # if the server response is bad, add code here to add a column to oa_articles that saves the response.status_code
                print('Bad URL response:', response.status_code, 'for', url)
                status_code.append(response.status_code)
        except Exception as e:
            print(f'{e} at index {idx} for url {url}')
            status_code.append(e)

    else:
        # add code here to add a column with note that there no PDF URL available
        print('No URL available from unpaywall')
        status_code.append('No URL available from unpaywall')
# Out:
# Bad URL response: 503 for https://onlinelibrary.wiley.com/doi/pdfdirect/10.1111/sms.14101
# No URL available from unpaywall
# No URL available from unpaywall
# No URL available from unpaywall
# No URL available from unpaywall
# No URL available from unpaywall
# Bad URL response: 503 for https://www.sciencedirect.com/science/article/am/pii/S1569904820302603
# No URL available from unpaywall
# No URL available from unpaywall
# No URL available from unpaywall
# Bad URL response: 503 for https://onlinelibrary.wiley.com/doi/pdfdirect/10.1113/EP089045
# No URL available from unpaywall
# No URL available from unpaywall
# Bad URL response: 503 for https://www.sciencedirect.com/science/article/am/pii/S1871403X20305767
# Bad URL response: 503 for https://physoc.onlinelibrary.wiley.com/doi/pdfdirect/10.1113/EP088194
# Bad URL response: 503 for https://www.sciencedirect.com/science/article/am/pii/S1871403X20305974
# Bad URL response: 503 for https://physoc.onlinelibrary.wiley.com/doi/pdfdirect/10.1113/EP088322
# No URL available from unpaywall
# No URL available from unpaywall
# No URL available from unpaywall
# No URL available from unpaywall
# No URL available from unpaywall
# Bad URL response: 503 for https://www.tandfonline.com/doi/pdf/10.1080/17461391.2020.1797890?needAccess=true
# Bad URL response: 503 for https://onlinelibrary.wiley.com/doi/pdfdirect/10.1111/apha.13463
# No URL available from unpaywall
# Bad URL response: 503 for https://onlinelibrary.wiley.com/doi/pdfdirect/10.1111/psyp.13620
# Bad URL response: 503 for https://www.sciencedirect.com/science/article/am/pii/S0031938420304790
# No URL available from unpaywall
# No URL available from unpaywall
# No URL available from unpaywall
# No URL available from unpaywall
# Bad URL response: 503 for https://onlinelibrary.wiley.com/doi/pdfdirect/10.1111/liv.14618
# Bad URL response: 503 for https://www.tandfonline.com/doi/pdf/10.1080/02640414.2020.1843820?needAccess=true
# No URL available from unpaywall
# No URL available from unpaywall
# No URL available from unpaywall
# Bad URL response: 503 for https://onlinelibrary.wiley.com/doi/pdfdirect/10.1111/apa.15163
# Bad URL response: 503 for https://onlinelibrary.wiley.com/doi/pdfdirect/10.1111/sms.13835
# No URL available from unpaywall
# No URL available from unpaywall
# HTTPSConnectionPool(host='ulir.ul.ie', port=443): Max retries exceeded with url: /bitstream/10344/9226/2/Barry_2020_Monitoring.pdf (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1125)'))) at index 144 for url https://ulir.ul.ie/bitstream/10344/9226/2/Barry_2020_Monitoring.pdf
# Bad URL response: 503 for https://onlinelibrary.wiley.com/doi/pdfdirect/10.1111/sms.13802
# Bad URL response: 503 for https://onlinelibrary.wiley.com/doi/pdfdirect/10.1111/sms.13766
# No URL available from unpaywall
# No URL available from unpaywall
# No URL available from unpaywall
# Bad URL response: 503 for https://physoc.onlinelibrary.wiley.com/doi/pdfdirect/10.1113/JP279554
# No URL available from unpaywall
# No URL available from unpaywall
# No URL available from unpaywall
# No URL available from unpaywall
# No URL available from unpaywall
# Bad URL response: 503 for https://www.tandfonline.com/doi/pdf/10.1080/17461391.2019.1640288?needAccess=true
# Bad URL response: 503 for https://onlinelibrary.wiley.com/doi/pdfdirect/10.1002/ajh.25936
# No URL available from unpaywall
# No URL available from unpaywall
# No URL available from unpaywall
# No URL available from unpaywall
# No URL available from unpaywall
# No URL available from unpaywall
# No URL available from unpaywall
# No URL available from unpaywall
# No URL available from unpaywall
# No URL available from unpaywall
# Bad URL response: 503 for https://onlinelibrary.wiley.com/doi/pdfdirect/10.1111/sms.13627
# No URL available from unpaywall
# No URL available from unpaywall
# Bad URL response: 503 for https://www.tandfonline.com/doi/pdf/10.1080/09593985.2018.1488320?needAccess=true
# No URL available from unpaywall
# Bad URL response: 503 for https://physoc.onlinelibrary.wiley.com/doi/pdfdirect/10.1113/EP087726
# No URL available from unpaywall
# No URL available from unpaywall
# No URL available from unpaywall
# Bad URL response: 503 for https://physoc.onlinelibrary.wiley.com/doi/pdfdirect/10.1113/EP087727
# Bad URL response: 503 for https://physoc.onlinelibrary.wiley.com/doi/pdfdirect/10.1113/EP087916
# No URL available from unpaywall
# No URL available from unpaywall
# Bad URL response: 503 for https://physoc.onlinelibrary.wiley.com/doi/pdfdirect/10.1113/EP087979
# No URL available from unpaywall
# No URL available from unpaywall
# No URL available from unpaywall
# Bad URL response: 503 for https://onlinelibrary.wiley.com/doi/pdfdirect/10.1111/sms.13536
# No URL available from unpaywall
# Bad URL response: 503 for https://onlinelibrary.wiley.com/doi/pdfdirect/10.1096/fj.201802238R
# Bad URL response: 503 for https://physoc.onlinelibrary.wiley.com/doi/pdfdirect/10.1113/EP087864
# No URL available from unpaywall
# No URL available from unpaywall
# No URL available from unpaywall
# Bad URL response: 503 for https://physoc.onlinelibrary.wiley.com/doi/pdfdirect/10.1113/EP087599
# No URL available from unpaywall
# Bad URL response: 503 for https://www.onlinelibrary.wiley.com/doi/pdfdirect/10.1002/ejhf.1431
# No URL available from unpaywall
# No URL available from unpaywall
# No URL available from unpaywall
# No URL available from unpaywall
# No URL available from unpaywall
# No URL available from unpaywall
# Bad URL response: 503 for https://www.tandfonline.com/doi/pdf/10.1080/17461391.2019.1571112?needAccess=true
# Bad URL response: 503 for https://faseb.onlinelibrary.wiley.com/doi/pdfdirect/10.1096/fj.201802209R
# No URL available from unpaywall
# No URL available from unpaywall
# No URL available from unpaywall
# No URL available from unpaywall
# No URL available from unpaywall
# No URL available from unpaywall
# No URL available from unpaywall
# No URL available from unpaywall
# No URL available from unpaywall
# No URL available from unpaywall
# No URL available from unpaywall
# No URL available from unpaywall
# No URL available from unpaywall
# No URL available from unpaywall
# No URL available from unpaywall
# No URL available from unpaywall
# No URL available from unpaywall
# Bad URL response: 503 for https://www.tandfonline.com/doi/pdf/10.1080/00015385.2018.1478763?needAccess=true
# No URL available from unpaywall
# No URL available from unpaywall
# No URL available from unpaywall
# No URL available from unpaywall
# HTTPSConnectionPool(host='myresearchspace.uws.ac.uk', port=443): Max retries exceeded with url: /ws/files/1785870/Accepted_Author_Manuscript.pdf (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1125)'))) at index
# Bad URL response: 503 for https://physoc.onlinelibrary.wiley.com/doi/pdfdirect/10.1113/jphysiol.2004.065664
# No URL available from unpaywall
# No URL available from unpaywall
# No URL available from unpaywall
# Bad URL response: 503 for https://physoc.onlinelibrary.wiley.com/doi/pdfdirect/10.1113/jphysiol.2003.056887
# Bad URL response: 503 for https://physoc.onlinelibrary.wiley.com/doi/pdfdirect/10.1113/jphysiol.2003.056598
# No URL available from unpaywall
# No URL available from unpaywall
# Bad URL response: 503 for https://physoc.onlinelibrary.wiley.com/doi/pdfdirect/10.1113/jphysiol.2003.052431
# Bad URL response: 503 for https://physoc.onlinelibrary.wiley.com/doi/pdfdirect/10.1113/jphysiol.2003.045799
# Bad URL response: 503 for https://physoc.onlinelibrary.wiley.com/doi/pdfdirect/10.1113/jphysiol.2003.040162
# Bad URL response: 503 for https://physoc.onlinelibrary.wiley.com/doi/pdfdirect/10.1113/jphysiol.2003.039743
# Bad URL response: 503 for https://physoc.onlinelibrary.wiley.com/doi/pdfdirect/10.1113/jphysiol.2003.040147
# No URL available from unpaywall
# No URL available from unpaywall
# No URL available from unpaywall
# Bad URL response: 503 for https://iai.asm.org/content/70/11/6273.full.pdf
# Bad URL response: 503 for https://physoc.onlinelibrary.wiley.com/doi/pdfdirect/10.1113/jphysiol.2002.029108
# Bad URL response: 503 for https://physoc.onlinelibrary.wiley.com/doi/pdfdirect/10.1113/jphysiol.2002.028084
# Bad URL response: 503 for https://physoc.onlinelibrary.wiley.com/doi/pdfdirect/10.1113/jphysiol.2002.023556
# Bad URL response: 503 for https://bpspubs.onlinelibrary.wiley.com/doi/pdfdirect/10.1038/sj.bjp.0704949
# Bad URL response: 503 for https://physoc.onlinelibrary.wiley.com/doi/pdfdirect/10.1113/jphysiol.2002.023796
# Bad URL response: 503 for https://physoc.onlinelibrary.wiley.com/doi/pdfdirect/10.1113/jphysiol.2002.019380
# Bad URL response: 503 for https://physoc.onlinelibrary.wiley.com/doi/pdfdirect/10.1113/jphysiol.2002.019661
# No URL available from unpaywall
# No URL available from unpaywall
# No URL available from unpaywall
# Bad URL response: 503 for https://physoc.onlinelibrary.wiley.com/doi/pdfdirect/10.1113/jphysiol.2002.016832
# Bad URL response: 503 for https://physoc.onlinelibrary.wiley.com/doi/pdfdirect/10.1113/jphysiol.2001.012983
# Bad URL response: 503 for https://physoc.onlinelibrary.wiley.com/doi/pdfdirect/10.1113/jphysiol.2001.013062
# No URL available from unpaywall
# Bad URL response: 503 for https://physoc.onlinelibrary.wiley.com/doi/pdfdirect/10.1111/j.1469-7793.2001.0305k.x
# Bad URL response: 503 for https://physoc.onlinelibrary.wiley.com/doi/pdfdirect/10.1111/j.1469-7793.2001.00295.x
# Bad URL response: 503 for https://physoc.onlinelibrary.wiley.com/doi/pdfdirect/10.1111/j.1469-7793.2001.00283.x
# No URL available from unpaywall
# Bad URL response: 503 for https://physoc.onlinelibrary.wiley.com/doi/pdfdirect/10.1111/j.1469-7793.2001.t01-1-00891.x
# No URL available from unpaywall
# No URL available from unpaywall
# No URL available from unpaywall
# Bad URL response: 503 for https://physoc.onlinelibrary.wiley.com/doi/pdfdirect/10.1111/j.1469-7793.2000.t01-1-00647.x
# No URL available from unpaywall
# Bad URL response: 503 for https://physoc.onlinelibrary.wiley.com/doi/pdfdirect/10.1111/j.1469-7793.2000.t01-1-00221.x
# Bad URL response: 503 for https://physoc.onlinelibrary.wiley.com/doi/pdfdirect/10.1111/j.1469-7793.2000.t01-1-00003.x
# No URL available from unpaywall
# No URL available from unpaywall
# Bad URL response: 503 for https://physoc.onlinelibrary.wiley.com/doi/pdfdirect/10.1111/j.1469-7793.2000.00211.x
# Bad URL response: 503 for https://physoc.onlinelibrary.wiley.com/doi/pdfdirect/10.1111/j.1469-7793.2000.t01-2-00159.xm
# No URL available from unpaywall
# Bad URL response: 503 for https://physoc.onlinelibrary.wiley.com/doi/pdfdirect/10.1111/j.1469-7793.1999.0911n.x
# Bad URL response: 503 for https://physoc.onlinelibrary.wiley.com/doi/pdfdirect/10.1111/j.1469-7793.1999.0933p.x
# No URL available from unpaywall
# Bad URL response: 503 for https://physoc.onlinelibrary.wiley.com/doi/pdfdirect/10.1111/j.1469-7793.1999.293af.x
# No URL available from unpaywall
# Bad URL response: 503 for https://physoc.onlinelibrary.wiley.com/doi/pdfdirect/10.1111/j.1469-7793.1998.889ba.x
# Bad URL response: 503 for https://onlinelibrary.wiley.com/doi/pdfdirect/10.1002/clc.4960210904
# No URL available from unpaywall
# No URL available from unpaywall
# No URL available from unpaywall
# No URL available from unpaywall
# Bad URL response: 503 for https://physoc.onlinelibrary.wiley.com/doi/pdfdirect/10.1111/j.1469-7793.1997.703bm.x
# No URL available from unpaywall
# Bad URL response: 503 for https://physoc.onlinelibrary.wiley.com/doi/pdfdirect/10.1111/j.1469-7793.1997.455bn.x
# Bad URL response: 503 for https://physoc.onlinelibrary.wiley.com/doi/pdfdirect/10.1113/jphysiol.1997.sp021972
# No URL available from unpaywall
# No URL available from unpaywall
# No URL available from unpaywall
# No URL available from unpaywall
# Bad URL response: 503 for https://physoc.onlinelibrary.wiley.com/doi/pdfdirect/10.1113/jphysiol.1996.sp021592
# Bad URL response: 503 for https://physoc.onlinelibrary.wiley.com/doi/pdfdirect/10.1113/jphysiol.1996.sp021540
# No URL available from unpaywall
# No URL available from unpaywall
# No URL available from unpaywall
# No URL available from unpaywall
# No URL available from unpaywall
# Bad URL response: 503 for https://physoc.onlinelibrary.wiley.com/doi/pdfdirect/10.1113/jphysiol.1995.sp020533
# No URL available from unpaywall
# Bad URL response: 503 for https://physoc.onlinelibrary.wiley.com/doi/pdfdirect/10.1113/jphysiol.1994.sp020077
# No URL available from unpaywall
# Bad URL response: 503 for https://bpspubs.onlinelibrary.wiley.com/doi/pdfdirect/10.1111/j.1365-2125.1994.tb04390.x
# No URL available from unpaywall
# No URL available from unpaywall
# No URL available from unpaywall
# No URL available from unpaywall
# Bad URL response: 503 for https://physoc.onlinelibrary.wiley.com/doi/pdfdirect/10.1113/jphysiol.1993.sp019923
# No URL available from unpaywall
# No URL available from unpaywall
# Bad URL response: 503 for https://bpspubs.onlinelibrary.wiley.com/doi/pdfdirect/10.1111/j.1365-2125.1992.tb04020.x
# Bad URL response: 503 for https://physoc.onlinelibrary.wiley.com/doi/pdfdirect/10.1113/jphysiol.1991.sp018594
# Bad URL response: 503 for https://physoc.onlinelibrary.wiley.com/doi/pdfdirect/10.1113/jphysiol.1991.sp018852
# Bad URL response: 503 for https://physoc.onlinelibrary.wiley.com/doi/pdfdirect/10.1113/jphysiol.1991.sp018764
# No URL available from unpaywall
# Bad URL response: 503 for https://physoc.onlinelibrary.wiley.com/doi/pdfdirect/10.1113/jphysiol.1990.sp017912
# No URL available from unpaywall
# Bad URL response: 503 for http://www.pnas.org/content/85/23/8780.full.pdf
# Bad URL response: 503 for https://physoc.onlinelibrary.wiley.com/doi/pdfdirect/10.1113/jphysiol.1988.sp017365
# No URL available from unpaywall
# Bad URL response: 503 for https://physoc.onlinelibrary.wiley.com/doi/pdfdirect/10.1113/jphysiol.1988.sp016966
# No URL available from unpaywall
# Bad URL response: 503 for https://bpspubs.onlinelibrary.wiley.com/doi/pdfdirect/10.1111/j.1365-2125.1988.tb03323.x
# No URL available from unpaywall
# No URL available from unpaywall
# Bad URL response: 503 for https://physoc.onlinelibrary.wiley.com/doi/pdfdirect/10.1113/jphysiol.1987.sp016809
# Bad URL response: 503 for https://physoc.onlinelibrary.wiley.com/doi/pdfdirect/10.1113/jphysiol.1987.sp016701
# Bad URL response: 503 for https://bpspubs.onlinelibrary.wiley.com/doi/pdfdirect/10.1111/j.1365-2125.1987.tb03234.x
# Bad URL response: 503 for https://physoc.onlinelibrary.wiley.com/doi/pdfdirect/10.1113/jphysiol.1987.sp016543
# Bad URL response: 503 for https://physoc.onlinelibrary.wiley.com/doi/pdfdirect/10.1113/jphysiol.1987.sp016722
# No URL available from unpaywall
# No URL available from unpaywall
# Bad URL response: 503 for https://bpspubs.onlinelibrary.wiley.com/doi/pdfdirect/10.1111/j.1365-2125.1987.tb03183.x
# Bad URL response: 503 for https://bpspubs.onlinelibrary.wiley.com/doi/pdfdirect/10.1111/j.1365-2125.1987.tb03166.x
# Bad URL response: 503 for https://bpspubs.onlinelibrary.wiley.com/doi/pdfdirect/10.1111/j.1365-2125.1986.tb05226.x
# Bad URL response: 503 for https://physoc.onlinelibrary.wiley.com/doi/pdfdirect/10.1113/jphysiol.1986.sp016292
# No URL available from unpaywall
# Bad URL response: 503 for https://bpspubs.onlinelibrary.wiley.com/doi/pdfdirect/10.1111/j.1365-2125.1986.tb02853.x
# Bad URL response: 503 for https://bpspubs.onlinelibrary.wiley.com/doi/pdfdirect/10.1111/j.1365-2125.1985.tb05127.x
# No URL available from unpaywall
# Bad URL response: 503 for https://journals.sagepub.com/doi/pdf/10.1177/014107688507800505
# Bad URL response: 503 for https://bpspubs.onlinelibrary.wiley.com/doi/pdfdirect/10.1111/j.1365-2125.1985.tb05164.x
# Bad URL response: 503 for https://physoc.onlinelibrary.wiley.com/doi/pdfdirect/10.1113/jphysiol.1985.sp015557
# Bad URL response: 503 for http://www.pnas.org/content/82/18/6349.full.pdf
# Bad URL response: 503 for https://bpspubs.onlinelibrary.wiley.com/doi/pdfdirect/10.1111/j.1365-2125.1985.tb05161.x
# Bad URL response: 503 for https://bpspubs.onlinelibrary.wiley.com/doi/pdfdirect/10.1111/j.1365-2125.1985.tb02628.x
# Bad URL response: 503 for https://bpspubs.onlinelibrary.wiley.com/doi/pdfdirect/10.1111/j.1365-2125.1984.tb02411.x
# Bad URL response: 503 for https://bpspubs.onlinelibrary.wiley.com/doi/pdfdirect/10.1111/j.1365-2125.1984.tb02339.x
# Bad URL response: 503 for https://physoc.onlinelibrary.wiley.com/doi/pdfdirect/10.1113/jphysiol.1984.sp015408
# Bad URL response: 503 for https://physoc.onlinelibrary.wiley.com/doi/pdfdirect/10.1113/jphysiol.1984.sp015407
# Bad URL response: 503 for https://physoc.onlinelibrary.wiley.com/doi/pdfdirect/10.1113/jphysiol.1984.sp015412
# Bad URL response: 503 for https://bpspubs.onlinelibrary.wiley.com/doi/pdfdirect/10.1111/j.1365-2125.1984.tb02393.x
# Bad URL response: 503 for https://bpspubs.onlinelibrary.wiley.com/doi/pdfdirect/10.1111/j.1365-2125.1984.tb02412.x
# No URL available from unpaywall
# Bad URL response: 503 for https://bpspubs.onlinelibrary.wiley.com/doi/pdfdirect/10.1111/j.1365-2125.1983.tb02228.x
# Bad URL response: 503 for https://physoc.onlinelibrary.wiley.com/doi/pdfdirect/10.1113/jphysiol.1983.sp014925
# Bad URL response: 503 for https://bpspubs.onlinelibrary.wiley.com/doi/pdfdirect/10.1111/j.1365-2125.1983.tb01511.x
# No URL available from unpaywall
# Bad URL response: 503 for https://bpspubs.onlinelibrary.wiley.com/doi/pdfdirect/10.1111/j.1365-2125.1983.tb02211.x
# Bad URL response: 503 for https://bpspubs.onlinelibrary.wiley.com/doi/pdfdirect/10.1111/j.1365-2125.1983.tb02168.x
# Bad URL response: 503 for https://bpspubs.onlinelibrary.wiley.com/doi/pdfdirect/10.1111/j.1365-2125.1982.tb01900.x

# %%
articles = pd.read_csv('/Users/antonhesse/Desktop/Anton/Education/UMN/Lab and Research/HSPL/CPET_data_analysis/data/cpet_articles/ovid/unpaywall_info.csv')
oa_articles = articles[articles['is_oa'] == True].reset_index(drop=True)
status_code = []

for idx, row in oa_articles.iterrows():

    url = Unpywall.get_pdf_link(doi = row.doi_url)
    
    if url:
        # this just checks to make sure there's a URL before sending the request
        try:
            headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.15; rv:100.0) Gecko/20100101 Firefox/100.0'}
            response = requests.get(url, headers = headers)
            status_code.append(response.status_code)
            
        except Exception as e:
            print(f'{e} at index {idx} for url {url}')
            status_code.append(e)

    else:
        # add code here to add a column with note that there no PDF URL available
        print('No URL available from unpaywall')
        status_code.append('No URL available from unpaywall')
# Out:
# No URL available from unpaywall
# No URL available from unpaywall
# No URL available from unpaywall
# No URL available from unpaywall
# No URL available from unpaywall
# No URL available from unpaywall
# No URL available from unpaywall

# %%
status_code
# Out:
# [503, 'No URL available from unpaywall', 200, 200]
