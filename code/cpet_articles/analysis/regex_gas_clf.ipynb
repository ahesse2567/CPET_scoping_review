# %%
import pandas as pd
import re
import glob
from pathlib import Path
from tqdm.notebook import tqdm
from langdetect import detect
import sys
sys.path.append('code/cpet_articles/analysis/')
from article_screening_re import *

import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer
import numpy as np
# from nltk.probability import FreqDist

# import random
# import pandas as pd

# # import requests

# import pickle
# import time

# %%
txt_files = glob.glob('/Users/antonhesse/Desktop/Anton/Education/UMN/Lab and Research/HSPL/CPET_scoping_review/data/cpet_articles/txts/*.txt')
gas_clf_df = pd.read_csv('/Users/antonhesse/Desktop/Anton/Education/UMN/Lab and Research/HSPL/CPET_scoping_review/data/cpet_articles/Manual text analysis - exer.csv')
gas_clf_df['txt_file_name'] = gas_clf_df.apply(lambda x: str(x['Article'] + '.txt'), axis=1)
# gas_clf_df = gas_clf_df[(gas_clf_df['Eligible'] == 'e') & (gas_clf_df['External ref'] == 'n')].reset_index(drop=True)

# %%
for idx, row in gas_clf_df.iterrows():
    if row['Eligible'] != 'e':
        row['Gas data'] = 'n'
    if (row['External ref'] == 'y') & (row['Gas data'] != 'y'):
        row['Gas data'] = 'n'

# %%
def process_file_one_string(file_name, file_list):
    txt_re = re.compile(file_name)
    fname = list(filter(txt_re.search, file_list))[0]
    
    # check file size to make sure the txt file actually has text
    file_size = 0
    while file_size == 0:
        file_size = Path(fname).stat().st_size
        if file_size != 0: # check if conversion to txt didn't work
            with open(fname, 'r') as f:
                text = f.read()
        else:
            print('Empty file, returning None')
            return None
    text_lower = text.lower()
    
    return text_lower

# %%
def process_file(file_name, file_list, mode = 'lemm'):
    txt_re = re.compile(file_name)
    fname = list(filter(txt_re.search, file_list))[0]
    
    # check file size to make sure the txt file actually has text
    file_size = 0
    while file_size == 0:
        file_size = Path(fname).stat().st_size
        if file_size != 0: # check if conversion to txt didn't work
            with open(fname, 'r') as f:
                text = f.read()
        else:
            print('Empty file, returning None')
            return None
    text_lower = text.lower()
    tokens = word_tokenize(text_lower)
    stop_words = set(stopwords.words('english'))

    filtered_tokens = [t for t in tokens if t not in stop_words]
    
    if mode == 'lemm':
        lemmatizer = WordNetLemmatizer()
        lemmatized_words = [lemmatizer.lemmatize(t) for t in filtered_tokens]

        return lemmatized_words
    
    elif mode == 'stem':
        stemmer = PorterStemmer()
        stemmed_words = [stemmer.stem(t) for t in filtered_tokens]
    
        return stemmed_words

# %%
analyzed_txt_files = gas_clf_df['txt_file_name'].to_list()

# %%
token_word_lists = [process_file(f, txt_files, mode='lemm') for f in tqdm(analyzed_txt_files)]
long_word_lists = [process_file_one_string(f, txt_files) for f in tqdm(analyzed_txt_files)]
# Out:
#   0%|          | 0/380 [00:00<?, ?it/s]
#   0%|          | 0/380 [00:00<?, ?it/s]

# %%
gas_clf_df['article_text'] = long_word_lists
gas_clf_df['tokens'] = token_word_lists
gas_clf_df['avg_word_len'] = gas_clf_df.apply(lambda x: np.mean(list(map(len, x['tokens']))), axis=1)
gas_clf_df = gas_clf_df[gas_clf_df['avg_word_len'] > 1.5].reset_index(drop=True) # removes articles with pdf to txt conversion issue

# %%
gas_clf_df['language'] = gas_clf_df.apply(lambda x: detect(x['article_text']), axis=1)
# gas_clf_df['language'].value_counts()

# %%
# filtering by enlglish or Welch lol
gas_clf_df = gas_clf_df[gas_clf_df['language'].isin(['en', 'cy'])].reset_index(drop=True)

# %%
def oxygen_uptake_re(text):
    o2_uptake_re = re.compile(r'oxygen.{0,5}uptake', re.DOTALL)
    o2_consumption_re = re.compile(r'oxyen.{0,5}consumption', re.DOTALL)
    vo2max_re = re.compile(r'(v)?o2.{0,2}(max)?', re.DOTALL)
    vo2peak_re = re.compile(r'(v)?o2.{0,2}(peak)?', re.DOTALL)
    aerobic_power_re = re.compile(r'aerobic.{0,2}power', re.DOTALL)
    
    mo_list = [
        o2_uptake_re.search(text),
        o2_consumption_re.search(text),
    vo2max_re.search(text),
    vo2peak_re.search(text),
    aerobic_power_re.search(text)]
    
    mentions_o2_uptake = any(mo is not None for mo in mo_list)
    
    return mentions_o2_uptake

def gas_collection_methods_re(text):
    bbb_re = re.compile(r'breath.{0,5}breath', re.DOTALL)
    douglas_bag_re = re.compile(r'douglas.{0,5}bag', re.DOTALL)
    mixing_chamber_re = re.compile(r'mixing.{0,5}chamber', re.DOTALL)
    
    mo_list = [bbb_re.search(text), douglas_bag_re.search(text), mixing_chamber_re.search(text)]
    
    gas_methods = any(mo is not None for mo in mo_list)
    
    return gas_methods

def vo2_units_re(text):
    mL_kg_min_re = re.compile(r'ml[^a-zA-Z]*kg[^a-zA-Z]*min')
    mL_min_kg_re = re.compile(r'ml[^a-zA-Z]*min[^a-zA-Z]*kg')
    
    # L_mL_min = re.compile(r'(m)?l[^a-zA-Z]*min')

    mo_list = [mL_kg_min_re.search(text), mL_min_kg_re.search(text)]
    
    vo2_units = any(mo is not None for mo in mo_list)
    
    return vo2_units

# %%
gas_clf_df['o2_uptake'] = gas_clf_df.apply(lambda x: oxygen_uptake_re(x['article_text']), axis=1)
gas_clf_df['vo2_units'] = gas_clf_df.apply(lambda x: vo2_units_re(x['article_text']), axis=1)
gas_clf_df['gas_collection_methods'] = gas_clf_df.apply(lambda x: gas_collection_methods_re(x['article_text']), axis=1)

# %%
pd.crosstab(gas_clf_df['Gas data'], gas_clf_df['o2_uptake'])
# Out:
# o2_uptake  False  True
# Gas data
# n             19   105
# y              0   234

# %%
gas_clf_df[(gas_clf_df['Gas data'] == 'n') & (gas_clf_df['o2_uptake'] == True)]
# Out:
#                      Article Eligible Eligibility note External ref Gas data  \
# 1                 sjweh.2914        e              NaN            n        n
# 7             systems2040425        e              NaN            n        n
# 15        s40798-021-00363-1        e              NaN            n        n
# 21        s40279-019-01103-y        e              NaN            n        n
# 22        s41467-019-10925-3        e              NaN            n        n
# ..                       ...      ...              ...          ...      ...
# 351                jeb.02440        i        Non-human          NaN        n
# 352      j.msard.2022.103721        e              NaN            n        n
# 354        s00421-006-0181-1        i        Not OP-RR          NaN        n
# 355     mss.0000000000001204        i        Not OP-RR          NaN        n
# 356  s0066-782x2002001200004        e              NaN            n        n
#
#                    txt_file_name  \
# 1                 sjweh.2914.txt
# 7             systems2040425.txt
# 15        s40798-021-00363-1.txt
# 21        s40279-019-01103-y.txt
# 22        s41467-019-10925-3.txt
# ..                           ...
# 351                jeb.02440.txt
# 352      j.msard.2022.103721.txt
# 354        s00421-006-0181-1.txt
# 355     mss.0000000000001204.txt
# 356  s0066-782x2002001200004.txt
#
#                                           article_text  \
# 1    downloaded from www.sjweh.fi on may 26, 2022\n...
# 7    systems 2014, 2, 425-450; doi:10.3390/systems2...
# 15   most et al. sports med - open            (2021...
# 21   sports medicine (2019) 49:1465–1473 \nhttps://...
# 22   article\n\nhttps://doi.org/10.1038/s41467-019-...
# ..                                                 ...
# 351  3940\n\nthe journal of experimental biology 20...
# 352  contents lists available at sciencedirect \n\n...
# 354  grimmer et al. journal of neuroengineering and...
# 355   \n\n. . . published ahead of print \n \n \n \...
# 356  arq  bras  cardiol\n2002;  79:  239-44.\n\nori...
#
#                                                 tokens  avg_word_len language  \
# 1    [downloaded, www.sjweh.fi, may, 26, ,, 2022, s...      4.782363       en
# 7    [system, 2014, ,, 2, ,, 425-450, ;, doi:10.339...      4.628654       en
# 15   [et, al, ., sport, med, -, open, (, 2021, ), 7...      4.669721       en
# 21   [sport, medicine, (, 2019, ), 49:1465–1473, ht...      4.783203       en
# 22   [article, http, :, //doi.org/10.1038/s41467-01...      4.529885       en
# ..                                                 ...           ...      ...
# 351  [3940, journal, experimental, biology, 209, ,,...      4.784446       en
# 352  [content, list, available, sciencedirect, mult...      4.775318       en
# 354  [grimmer, et, al, ., journal, neuroengineering...      4.421915       en
# 355  [., ., ., published, ahead, print, meta-analys...      4.594075       en
# 356  [arq, bra, cardiol, 2002, ;, 79, :, 239-44., o...      5.021489       en
#
#      o2_uptake  vo2_units  gas_collection_methods
# 1         True      False                   False
# 7         True      False                   False
# 15        True      False                   False
# 21        True      False                   False
# 22        True      False                   False
# ..         ...        ...                     ...
# 351       True       True                   False
# 352       True      False                   False
# 354       True       True                   False
# 355       True       True                   False
# 356       True       True                   False
#
# [105 rows x 13 columns]

# %%
pd.crosstab(gas_clf_df['Gas data'], gas_clf_df['gas_collection_methods'])
# Out:
# gas_collection_methods  False  True
# Gas data
# n                         122     3
# y                         140   103

# %%
gas_clf_df[(gas_clf_df['Gas data'] == 'n') & (gas_clf_df['gas_collection_methods'] == True)]
# Out:
#                      Article Eligible Eligibility note External ref Gas data  \
# 131     journal.pone.0140616        e              NaN            n        n
# 143  japplphysiol.00864.2015        i        Not OP-RR          NaN        n
# 159                   422056        i        Non-human          NaN        n
#
#                    txt_file_name  \
# 131     journal.pone.0140616.txt
# 143  japplphysiol.00864.2015.txt
# 159                   422056.txt
#
#                                           article_text language  vo2_units  \
# 131  research article\n\ninfluence of hypoxic inter...       en       True
# 143  j appl physiol 120: 481–494, 2016.\nfirst publ...       en       True
# 159  division of comparative physiology and biochem...       en       True
#
#      says_bbb  gas_collection_methods
# 131     False                    True
# 143      True                    True
# 159      True                    True

# %%
pd.crosstab(gas_clf_df['Gas data'], [gas_clf_df['gas_collection_methods'], gas_clf_df['vo2_units']])
# Out:
# gas_collection_methods False       True
# vo2_units              False True False True
# Gas data
# n                         92   30     0    3
# y                         45   95    16   87

# %%
gas_clf_df[(gas_clf_df['Gas data'] == 'y') & (gas_clf_df['vo2_units'] == False) & (gas_clf_df['gas_collection_methods'] == False)]
# Out:
#                          Article Eligible Eligibility note External ref  \
# 6                   thx.35.9.680        e              NaN            n
# 11                  tjem.233.135        e              NaN            n
# 52       s0100-879x2011007500073        e              NaN            n
# 60             s0007114521002208        e              NaN            n
# 62                    nu14091776        e              NaN            n
# 78             s00421-011-2129-3        e              NaN            n
# 81                  oem.34.2.126        e              NaN            n
# 91          journal.pone.0208452        e              NaN            n
# 93             jrrd.2007.09.0153        e              NaN            n
# 103         mss.0000000000001353        e              NaN            n
# 111         mss.0000000000000793        e              NaN            n
# 127             jjphysiol.23.645        e              NaN            n
# 137                 jc.2015-1339        e              NaN            n
# 141          jospt.1998.27.2.154        e              NaN            n
# 145                jomh.2021.111        e              NaN            n
# 146          jospt.1994.19.3.140        e              NaN            n
# 166             jjphysiol.33.971        e              NaN            n
# 168                   ihj.35.301        e              NaN            n
# 173  circheartfailure.113.000187        e              NaN            n
# 179           archpedi.161.6.561        e              NaN            n
# 180                 hrt.52.2.124        e              NaN            n
# 186            s12984-015-0099-0        e              NaN            n
# 191            01.atv.15.10.1668        e              NaN            n
# 202            j.wem.2014.06.011        e              NaN            n
# 211                   bf00695018        e              NaN            n
# 216            s00439-009-0731-9        e              NaN            n
# 220                s004210050218        e              NaN            n
# 228                   bf00697597        e              NaN            n
# 248                 jc.86.6.2525        e              NaN            n
# 250                   bf00357625        e              NaN            n
# 252                   bf00964107        e              NaN            n
# 253                   bf00865406        e              NaN            n
# 280      archrheumatol.2020.7548        e              NaN            n
# 282         jsc.0b013e318256bedc        e              NaN            n
# 305             medicina55070348        e              NaN            n
# 315               ijerph17113865        e              NaN            n
# 325       circimaging.120.010567        e              NaN            n
# 326                   bf00618488        e              NaN            n
# 327           ajpregu.00182.2018        e              NaN            n
# 346         09031936.04.00142903        e              NaN            n
# 347                 thx.44.9.716        e              NaN            n
# 348                bjsm.25.4.191        e              NaN            n
# 349            s00421-010-1709-y        e              NaN            y
# 351                bjsm.12.4.176        e              NaN            n
# 355            s00464-014-3691-7        e              NaN            n
#
#     Gas data                    txt_file_name  \
# 6          y                 thx.35.9.680.txt
# 11         y                 tjem.233.135.txt
# 52         y      s0100-879x2011007500073.txt
# 60         y            s0007114521002208.txt
# 62         y                   nu14091776.txt
# 78         y            s00421-011-2129-3.txt
# 81         y                 oem.34.2.126.txt
# 91         y         journal.pone.0208452.txt
# 93         y            jrrd.2007.09.0153.txt
# 103        y         mss.0000000000001353.txt
# 111        y         mss.0000000000000793.txt
# 127        y             jjphysiol.23.645.txt
# 137        y                 jc.2015-1339.txt
# 141        y          jospt.1998.27.2.154.txt
# 145        y                jomh.2021.111.txt
# 146        y          jospt.1994.19.3.140.txt
# 166        y             jjphysiol.33.971.txt
# 168        y                   ihj.35.301.txt
# 173        y  circheartfailure.113.000187.txt
# 179        y           archpedi.161.6.561.txt
# 180        y                 hrt.52.2.124.txt
# 186        y            s12984-015-0099-0.txt
# 191        y            01.atv.15.10.1668.txt
# 202        y            j.wem.2014.06.011.txt
# 211        y                   bf00695018.txt
# 216        y            s00439-009-0731-9.txt
# 220        y                s004210050218.txt
# 228        y                   bf00697597.txt
# 248        y                 jc.86.6.2525.txt
# 250        y                   bf00357625.txt
# 252        y                   bf00964107.txt
# 253        y                   bf00865406.txt
# 280        y      archrheumatol.2020.7548.txt
# 282        y         jsc.0b013e318256bedc.txt
# 305        y             medicina55070348.txt
# 315        y               ijerph17113865.txt
# 325        y       circimaging.120.010567.txt
# 326        y                   bf00618488.txt
# 327        y           ajpregu.00182.2018.txt
# 346        y         09031936.04.00142903.txt
# 347        y                 thx.44.9.716.txt
# 348        y                bjsm.25.4.191.txt
# 349        y            s00421-010-1709-y.txt
# 351        y                bjsm.12.4.176.txt
# 355        y            s00464-014-3691-7.txt
#
#                                           article_text language  vo2_units  \
# 6    thorax, 198), 35, 680-685\n\ncholinergic block...       en      False
# 11   tohoku j. exp. med., 2014, 233, 135-140\n\n135...       en      False
# 52   www.bjournal.com.br\nwww.bjournal.com.br\n\nis...       en      False
# 60   h\nt\nt\np\ns\n:\n/\n/\nd\no\n\ni\n.\n\n.\n\no...       en      False
# 62   article\neffects of trehalose solutions at dif...       en      False
# 78   university of montana \nuniversity of montana ...       en      False
# 81   british journal ofindustrial medicine, 1977, 3...       en      False
# 91   research article\neccentric cycling does not i...       en      False
# 93   jrrdjrrd volume 45, number 6, 2008\n\njournal ...       en      False
# 103  washington university school of medicine \nwas...       en      False
# 111  a\nc\nu\nt\ne\ne\nx\ne\nr\nc\ni\ns\ne\n-\ni\nn...       cy      False
# 127  宮 村 実 晴,  本 田 良行\n\nj\na\np\n.\n \nj\n.\n \np\...       cy      False
# 137  j c e m o n l i n e\n\na d v a n c e s\n\ni n ...       en      False
# 141  the effect of warm-up intensity on range of \n...       en      False
# 145  j. mens. health 2022; 18(2): 036\nhttp://doi.o...       en      False
# 146  the effects of nonswimming water exercises \no...       en      False
# 166  j\na\np\na\nn\ne\ns\ne\n \nj\no\nu\nr\nn\na\nl...       cy      False
# 168  e\nf\nf\ne\nc\nt\n \no\nf\n \nd\ni\ng\no\nx\ni...       cy      False
# 173  original article\n\nfailing heart of patients ...       en      False
# 179  article\n\nschool-based fitness changes are lo...       en      False
# 180  br heart j 1984; 52: 124-9\n\ncardiac structur...       en      False
# 186  nooijen et al. journal of neuroengineering and...       en      False
# 191  1668 \n\neffects of exercise training and deco...       en      False
# 202  wilderness & environmental medicine, 25, 462–4...       en      False
# 211  i\nn\nt\n.\n \nz\n.\n \na\nn\ng\ne\nw\n.\n \np...       cy      False
# 216  i\n\n-\n\nn\nh\np\na\na\nu\nh\no\nr\n \n\n \n\...       en      False
# 220  european journal of applied physiology (2019) ...       en      False
# 228  i\nn\nt\n.\n \nz\n.\n \na\nn\ng\ne\nw\n.\n \np...       cy      False
# 248  0021-972x/01/$03.00/0\nthe journal of clinical...       en      False
# 250  e\nu\nr\n \nj\n \na\np\np\nl\n \np\nh\ny\ns\ni...       cy      False
# 252  e\nu\nr\n \nj\n \na\np\np\ni\n \np\nh\ny\ns\ni...       cy      False
# 253  e\nu\nr\n \nj\n \na\np\np\nl\n \np\nh\ny\ns\ni...       cy      False
# 280  arch rheumatol 2020;35(1):97-106\n\nassessment...       en      False
# 282  university of wisconsin-la crosse \n\ngraduate...       en      False
# 305  article\nthe eﬀects of transdermal nicotine pa...       en      False
# 315  article\nsprint interval running and continuou...       en      False
# 325  circulation: cardiovascular imaging\n\nresearc...       en      False
# 326  167© springer international publishing switzer...       en      False
# 327  am j physiol regul integr comp physiol 315: r5...       en      False
# 346  eur respir j 2004; 24: 538–544\ndoi: 10.1183/0...       en      False
# 347  thorax 1989;44:716-720\n\nadverse effect of ad...       en      False
# 348  br j sp med 1991; 25(4)\n\nbrief exercise indu...       en      False
# 349  eur j appl physiol (2011) 111:827–837\ndoi 10....       en      False
# 351  176\n\nbrit.j.sports med.: 1979, 12, 176-178\n...       en      False
# 355  surg endosc (2015) 29:474–480\ndoi 10.1007/s00...       en      False
#
#      gas_collection_methods
# 6                     False
# 11                    False
# 52                    False
# 60                    False
# 62                    False
# 78                    False
# 81                    False
# 91                    False
# 93                    False
# 103                   False
# 111                   False
# 127                   False
# 137                   False
# 141                   False
# 145                   False
# 146                   False
# 166                   False
# 168                   False
# 173                   False
# 179                   False
# 180                   False
# 186                   False
# 191                   False
# 202                   False
# 211                   False
# 216                   False
# 220                   False
# 228                   False
# 248                   False
# 250                   False
# 252                   False
# 253                   False
# 280                   False
# 282                   False
# 305                   False
# 315                   False
# 325                   False
# 326                   False
# 327                   False
# 346                   False
# 347                   False
# 348                   False
# 349                   False
# 351                   False
# 355                   False
