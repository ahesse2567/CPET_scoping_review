# %%
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer
from nltk.probability import FreqDist
from pathlib import Path
import glob
import random
import pandas as pd
import re
# import requests
from tqdm.notebook import tqdm
from sklearn.model_selection import StratifiedKFold, cross_val_score, RepeatedStratifiedKFold, train_test_split, GridSearchCV
from nltk.classify.scikitlearn import SklearnClassifier
from sklearn.naive_bayes import MultinomialNB,BernoulliNB,GaussianNB,ComplementNB,CategoricalNB
from statistics import mean, stdev
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, TfidfTransformer
from sklearn.metrics import accuracy_score, confusion_matrix, ConfusionMatrixDisplay
from sklearn.linear_model import SGDClassifier, LogisticRegression
from sklearn.svm import SVC, LinearSVC, NuSVC
from sklearn.ensemble import VotingClassifier, RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
import matplotlib.pyplot as plt
import numpy as np
import pickle
import time

# %%
def process_file(file_name, file_list, mode = 'lemm'):
    txt_re = re.compile(file_name)
    fname = list(filter(txt_re.search, file_list))[0]
    
    # check file size to make sure the txt file actually has text
    file_size = 0
    while file_size == 0:
        file_size = Path(fname).stat().st_size
        if file_size != 0: # check if conversion to txt didn't work
            with open(fname, 'r') as f:
                text = f.read()
        else:
            print('Empty file, returning None')
            return None
    text_lower = text.lower()
    tokens = word_tokenize(text_lower)
    stop_words = set(stopwords.words('english'))

    filtered_tokens = [t for t in tokens if t not in stop_words]
    
    if mode == 'lemm':
        lemmatizer = WordNetLemmatizer()
        lemmatized_words = [lemmatizer.lemmatize(t) for t in filtered_tokens]

        return lemmatized_words
    
    elif mode == 'stem':
        stemmer = PorterStemmer()
        stemmed_words = [stemmer.stem(t) for t in filtered_tokens]
    
        return stemmed_words

# %%
txt_files = glob.glob('/Users/antonhesse/Desktop/Anton/Education/UMN/Lab and Research/HSPL/CPET_scoping_review/data/cpet_articles/txts/*.txt')
gas_clf_df = pd.read_csv('/Users/antonhesse/Desktop/Anton/Education/UMN/Lab and Research/HSPL/CPET_scoping_review/data/cpet_articles/Manual text analysis - Gas clf.csv')
gas_clf_df['txt_file_name'] = gas_clf_df.apply(lambda x: str(x['Article'] + '.txt'), axis=1)
# gas_clf_df = gas_clf_df[(gas_clf_df['Eligible'] == 'e') & (gas_clf_df['External ref'] == 'n')].reset_index(drop=True)

# %%
for idx, row in gas_clf_df.iterrows():
    if row['Eligible'] != 'e':
        row['Gas data'] = 'n'
    if (row['External ref'] == 'y') & (row['Gas data'] != 'y'):
        row['Gas data'] = 'n'

# %%
analyzed_txt_files = gas_clf_df['txt_file_name'].to_list()

# %%
word_lists = [process_file(f, txt_files, mode = 'lemm') for f in tqdm(analyzed_txt_files)]
# joined_word_lists = [' '.join(text) for text in word_lists]
# Out:
#   0%|          | 0/620 [00:00<?, ?it/s]

# %%
gas_clf_df['words'] = word_lists

# %% [markdown]
# ## Removing articles with pdf to txt word lengh issue
#
# Sometimes the pdf2txt.py file makes every character its own word. I'm going to remove them for the sake of simplicity

# %%
gas_clf_df['avg_word_len'] = gas_clf_df.apply(lambda x: np.mean(list(map(len, x['words']))), axis=1)
gas_clf_df = gas_clf_df[gas_clf_df['avg_word_len'] > 1.5]

# %%
fdist = FreqDist()
for word_l in tqdm(gas_clf_df['words']):
        for word in word_l:
            fdist[word] += 1
# Out:
#   0%|          | 0/604 [00:00<?, ?it/s]

# %%
fdist.most_common() # exercise is by far the most common word
# Out:
# [(',', 313552),
#  ('.', 223151),
#  (')', 124261),
#  ('(', 123542),
#  (';', 38446),
#  (':', 38132),
#  ('exercise', 22944),
#  ('%', 18398),
#  ('[', 18094),
#  (']', 18049),
#  ('p', 17703),
#  ('et', 16718),
#  ('±', 16016),
#  ('1', 15881),
#  ('study', 15306),
#  ('2', 14500),
#  ('=', 13426),
#  ('e', 13312),
#  ('j', 13256),
#  ('n', 12839),
#  ('r', 12564),
#  ('al', 12346),
#  ('effect', 10286),
#  ('3', 10018),
#  ('c', 9912),
#  ('test', 9125),
#  ('training', 8984),
#  ('muscle', 8833),
#  ('*', 8368),
#  ('group', 8223),
#  ('rate', 8017),
#  ('b', 7679),
#  ('5', 7662),
#  ('h', 7420),
#  ('4', 7383),
#  ('time', 7279),
#  ('performance', 6959),
#  ('level', 6700),
#  ('6', 6661),
#  ('0', 6529),
#  ('<', 6431),
#  ('oxygen', 6400),
#  ('data', 6388),
#  ('j.', 6376),
#  ('sport', 6335),
#  ('activity', 6324),
#  ('10', 6238),
#  ('l', 6214),
#  ('’', 6081),
#  ('mean', 6069),
#  ('body', 6048),
#  ('change', 6026),
#  ('increase', 6008),
#  ('value', 5872),
#  ('using', 5851),
#  ('physical', 5717),
#  ('subject', 5648),
#  ('patient', 5599),
#  ('blood', 5566),
#  ('result', 5562),
#  ('may', 5535),
#  ('heart', 5524),
#  ('control', 5420),
#  ('difference', 5364),
#  ('analysis', 5343),
#  ('response', 5276),
#  ('participant', 5260),
#  ('cell', 5224),
#  ('u', 4987),
#  ('f', 4936),
#  ('min', 4856),
#  ('de', 4809),
#  ('used', 4757),
#  ('&', 4727),
#  ('also', 4655),
#  ('g', 4644),
#  ('8', 4589),
#  ('physiol', 4589),
#  ('increased', 4507),
#  ('m.', 4456),
#  ('med', 4404),
#  ('table', 4382),
#  ('7', 4274),
#  ('al.', 4261),
#  ('fig', 4225),
#  ('running', 4192),
#  ('9', 4163),
#  ('trial', 4162),
#  ('-', 4065),
#  ('higher', 4025),
#  ('metabolic', 3994),
#  ('figure', 3994),
#  ('http', 3908),
#  ('one', 3907),
#  ('two', 3871),
#  ('20', 3853),
#  ('energy', 3844),
#  ('peak', 3842),
#  ('compared', 3824),
#  ('concentration', 3719),
#  ('mass', 3696),
#  ('however', 3674),
#  ('intensity', 3621),
#  ('/', 3581),
#  ('30', 3571),
#  ('maximal', 3556),
#  ('capacity', 3536),
#  ('power', 3529),
#  ('performed', 3529),
#  ('model', 3526),
#  ('lower', 3475),
#  ('human', 3447),
#  ('high', 3426),
#  ('age', 3416),
#  ('a.', 3390),
#  ('significant', 3367),
#  ('aerobic', 3341),
#  ('speed', 3327),
#  ('v', 3321),
#  ('individual', 3281),
#  ('condition', 3272),
#  ('12', 3253),
#  ('15', 3191),
#  ('different', 3147),
#  ('disease', 3130),
#  ('measured', 3129),
#  ('function', 3118),
#  ('work', 3080),
#  ('glucose', 3036),
#  ('day', 3024),
#  ('research', 3001),
#  ('0.05', 2984),
#  ('sci', 2919),
#  ('w', 2898),
#  ('athlete', 2894),
#  ('method', 2884),
#  ('total', 2881),
#  ('s.', 2881),
#  ('temperature', 2844),
#  ('found', 2828),
#  ('period', 2818),
#  ('reported', 2812),
#  ('factor', 2786),
#  ('measurement', 2734),
#  ('endurance', 2713),
#  ('health', 2713),
#  ('observed', 2689),
#  ('r.', 2657),
#  ('week', 2653),
#  ('university', 2644),
#  ('protein', 2624),
#  ('following', 2617),
#  ('o2', 2577),
#  ('walking', 2565),
#  ('|', 2548),
#  ('11', 2521),
#  ('year', 2512),
#  ('minute', 2499),
#  ('consumption', 2496),
#  ('weight', 2487),
#  ('c.', 2470),
#  ('uptake', 2462),
#  ('system', 2462),
#  ('p.', 2449),
#  ('appl', 2442),
#  ('shown', 2439),
#  ('pressure', 2427),
#  ('treadmill', 2426),
#  ('k', 2422),
#  ('volume', 2406),
#  ('mouse', 2394),
#  ('author', 2385),
#  ('similar', 2374),
#  ('sample', 2363),
#  ('present', 2356),
#  ('hr', 2344),
#  ('physiological', 2343),
#  ('variable', 2342),
#  ('fitness', 2335),
#  ('cycling', 2313),
#  ('journal', 2313),
#  ('low', 2303),
#  ('14', 2302),
#  ('doi', 2294),
#  ('three', 2283),
#  ('child', 2270),
#  ('could', 2262),
#  ('mitochondrial', 2259),
#  ('strength', 2239),
#  ('+', 2229),
#  ('treatment', 2224),
#  ('use', 2221),
#  ('fat', 2205),
#  ('significantly', 2204),
#  ('25', 2202),
#  ('type', 2190),
#  ('associated', 2185),
#  ('session', 2150),
#  ('risk', 2138),
#  ('vo2', 2128),
#  ('protocol', 2127),
#  ('13', 2124),
#  ('metabolism', 2123),
#  ('recovery', 2094),
#  ('d.', 2094),
#  ('male', 2091),
#  ('would', 2086),
#  ('–', 2083),
#  ('vo2max', 2080),
#  ('rest', 2070),
#  ('interval', 2065),
#  ('respectively', 2057),
#  ('lactate', 2044),
#  ('measure', 2041),
#  ('24', 2032),
#  ('water', 2031),
#  ('mm', 2026),
#  ('plasma', 2024),
#  ('16', 2020),
#  ('per', 2020),
#  ('review', 2004),
#  ('50', 2002),
#  ('cycle', 1988),
#  ('60', 1982),
#  ('0.001', 1951),
#  ('number', 1950),
#  ('relative', 1948),
#  ('greater', 1944),
#  ('reduced', 1943),
#  ('testing', 1940),
#  ('adult', 1923),
#  ('well', 1916),
#  ('due', 1910),
#  ('acid', 1906),
#  ('relationship', 1903),
#  ('science', 1898),
#  ('parameter', 1898),
#  ('stress', 1869),
#  ('intervention', 1858),
#  ('therefore', 1856),
#  ('h.', 1856),
#  ('40', 1848),
#  ('2014', 1826),
#  ('within', 1825),
#  ('18', 1822),
#  ('skeletal', 1821),
#  ('baseline', 1820),
#  ('medicine', 1809),
#  ('decrease', 1802),
#  ('showed', 1799),
#  ('e.', 1798),
#  ('healthy', 1796),
#  ('l.', 1787),
#  ('ratio', 1785),
#  ('2011', 1777),
#  ('2013', 1765),
#  ('g.', 1762),
#  ('respiratory', 1756),
#  ('woman', 1748),
#  ('100', 1747),
#  ('insulin', 1746),
#  ('men', 1741),
#  ('comparison', 1740),
#  ('expression', 1722),
#  ('female', 1705),
#  ('previous', 1697),
#  ('2015', 1691),
#  ('la', 1689),
#  ('standard', 1678),
#  ('2012', 1677),
#  ('clinical', 1677),
#  ('17', 1675),
#  ('index', 1670),
#  ('output', 1665),
#  ('first', 1663),
#  ('reduction', 1658),
#  ('2010', 1648),
#  ('tion', 1639),
#  ('2009', 1619),
#  ('cardiovascular', 1615),
#  ('>', 1615),
#  ('although', 1614),
#  ('x', 1612),
#  ('21', 1610),
#  ('maximum', 1605),
#  ('article', 1599),
#  ('95', 1597),
#  ('normal', 1592),
#  ('cost', 1592),
#  ('sd', 1590),
#  ('size', 1585),
#  ('fatigue', 1583),
#  ('tissue', 1579),
#  ('range', 1577),
#  ('pubmed', 1571),
#  ('based', 1568),
#  ('anaerobic', 1568),
#  ('flow', 1563),
#  ('crossref', 1558),
#  ('experiment', 1555),
#  ('2016', 1555),
#  ('pulmonary', 1554),
#  ('correlation', 1552),
#  ('sprint', 1550),
#  ('calculated', 1547),
#  ('second', 1544),
#  ('swimming', 1544),
#  ('t.', 1533),
#  ('acute', 1531),
#  ('thus', 1531),
#  ('duration', 1526),
#  ('cardiac', 1525),
#  ('k.', 1523),
#  ('gene', 1520),
#  ('addition', 1516),
#  ('load', 1515),
#  ('19', 1506),
#  ('show', 1504),
#  ('obtained', 1500),
#  ('leg', 1498),
#  ('2007', 1494),
#  ('1.', 1490),
#  ('le', 1489),
#  ('point', 1486),
#  ('re', 1484),
#  ('determined', 1482),
#  ('vs.', 1482),
#  ('b.', 1479),
#  ('outcome', 1472),
#  ('22', 1470),
#  ('2017', 1468),
#  ('role', 1461),
#  ('2008', 1461),
#  ('supplementation', 1454),
#  ('ml', 1450),
#  ('statistical', 1450),
#  ('mechanism', 1449),
#  ('\x00', 1444),
#  ('characteristic', 1439),
#  ('phase', 1436),
#  ('physiology', 1436),
#  ('important', 1432),
#  ('”', 1427),
#  ('average', 1416),
#  ('0.01', 1413),
#  ('diabetes', 1412),
#  ('distance', 1406),
#  ('related', 1397),
#  ('⫾', 1394),
#  ('2006', 1392),
#  ('−', 1389),
#  ('experimental', 1386),
#  ('cm', 1384),
#  ('state', 1384),
#  ('exerc', 1382),
#  ('young', 1378),
#  ('production', 1377),
#  ('2018', 1375),
#  ('among', 1373),
#  ('player', 1371),
#  ('decreased', 1367),
#  ('kg', 1365),
#  ('velocity', 1363),
#  ('“', 1361),
#  ('without', 1353),
#  ('resting', 1348),
#  ('potential', 1348),
#  ('chronic', 1340),
#  ('force', 1336),
#  ('23', 1332),
#  ('resistance', 1323),
#  ('run', 1321),
#  ('evidence', 1318),
#  ('2004', 1316),
#  ('score', 1316),
#  ('runner', 1315),
#  ('eur', 1311),
#  ('possible', 1310),
#  ('signiﬁcant', 1309),
#  ('int', 1305),
#  ('oxidative', 1302),
#  ('2005', 1296),
#  ('association', 1290),
#  ('included', 1286),
#  ('post', 1284),
#  ('2019', 1279),
#  ('left', 1278),
#  ('available', 1275),
#  ('finding', 1271),
#  ('line', 1269),
#  ('gas', 1268),
#  ('population', 1268),
#  ('max', 1266),
#  ('‘', 1265),
#  ('?', 1260),
#  ('diet', 1259),
#  ('moderate', 1248),
#  ('assessment', 1243),
#  ('2000', 1239),
#  ('animal', 1235),
#  ('ing', 1230),
#  ('biol', 1229),
#  ('adaptation', 1228),
#  ('current', 1222),
#  ('trained', 1220),
#  ('rat', 1209),
#  ('2.', 1198),
#  ('ci', 1195),
#  ('80', 1194),
#  ('26', 1192),
#  ('published', 1191),
#  ('end', 1190),
#  ('given', 1187),
#  ('28', 1182),
#  ('arm', 1176),
#  ('likely', 1173),
#  ('pattern', 1168),
#  ('oxidation', 1165),
#  ('applied', 1163),
#  ('f.', 1162),
#  ('small', 1160),
#  ('2002', 1155),
#  ('heat', 1154),
#  ('determine', 1153),
#  ('2003', 1151),
#  ('assessed', 1150),
#  ('including', 1149),
#  ('previously', 1146),
#  ('usa', 1145),
#  ('2001', 1144),
#  ('effort', 1143),
#  ('set', 1139),
#  ('new', 1136),
#  ('serum', 1129),
#  ('procedure', 1128),
#  ('prior', 1128),
#  ('sex', 1127),
#  ('content', 1124),
#  ('according', 1121),
#  ('van', 1119),
#  ('27', 1118),
#  ('right', 1115),
#  ('loss', 1115),
#  ('reference', 1114),
#  ('elite', 1112),
#  ('active', 1109),
#  ('care', 1108),
#  ('km', 1107),
#  ('lung', 1106),
#  ('program', 1103),
#  ('threshold', 1102),
#  ('35', 1099),
#  ('hour', 1096),
#  ('whether', 1095),
#  ('presented', 1082),
#  ('improvement', 1080),
#  ('intake', 1076),
#  ('interaction', 1074),
#  ('frequency', 1073),
#  ('29', 1072),
#  ('described', 1072),
#  ('2020', 1067),
#  ('large', 1066),
#  ('placebo', 1065),
#  ('impact', 1062),
#  ('ergometer', 1061),
#  ('main', 1056),
#  ('n.', 1055),
#  ('medical', 1054),
#  ('clin', 1047),
#  ('br', 1045),
#  ('exposure', 1045),
#  ('functional', 1037),
#  ('fish', 1036),
#  ('either', 1033),
#  ('laboratory', 1029),
#  ('increasing', 1028),
#  ('w.', 1025),
#  ('four', 1023),
#  ('ventricular', 1023),
#  ('influence', 1014),
#  ('con', 1013),
#  ('bmi', 1011),
#  ('31', 1009),
#  ('height', 1009),
#  ('recorded', 1006),
#  ('constant', 1003),
#  ('pmid', 1000),
#  ('might', 998),
#  ('development', 997),
#  ('manuscript', 996),
#  ('across', 996),
#  ('term', 995),
#  ('order', 992),
#  ('see', 990),
#  ('signiﬁcantly', 987),
#  ('@', 986),
#  ('90', 982),
#  ('injury', 980),
#  ('exhaustion', 975),
#  ('34', 973),
#  ('cardiorespiratory', 972),
#  ('32', 971),
#  ('45', 970),
#  ('design', 969),
#  ('page', 969),
#  ('considered', 968),
#  ('percentage', 966),
#  ('light', 965),
#  ('least', 963),
#  ('failure', 961),
#  ('variation', 960),
#  ('lipid', 959),
#  ('provided', 956),
#  ('part', 954),
#  ('position', 954),
#  ('en', 954),
#  ('carbohydrate', 953),
#  ('submaximal', 951),
#  ('·', 950),
#  ('expressed', 949),
#  ('plo', 949),
#  ('several', 943),
#  ('case', 942),
#  ('expenditure', 939),
#  ('3.', 937),
#  ('even', 936),
#  ('bout', 935),
#  ('glycogen', 935),
#  ('area', 932),
#  ('obesity', 932),
#  ('33', 931),
#  ('additional', 928),
#  ('criterion', 927),
#  ('support', 926),
#  ('da', 924),
#  ('since', 923),
#  ('dietary', 920),
#  ('american', 920),
#  ('demonstrated', 915),
#  ('required', 914),
#  ('2021', 911),
#  ('•', 911),
#  ('perceived', 909),
#  ('sediment', 907),
#  ('#', 905),
#  ('repeated', 905),
#  ('×', 904),
#  ('regression', 901),
#  ('material', 899),
#  ('equation', 899),
#  ('specific', 897),
#  ('food', 896),
#  ('caffeine', 894),
#  ('report', 893),
#  ('37', 890),
#  ('con-', 890),
#  ('common', 888),
#  ('respiration', 884),
#  ('stroke', 883),
#  ('ability', 882),
#  ('whereas', 882),
#  ('se', 881),
#  ('amount', 879),
#  ('36', 878),
#  ('improve', 874),
#  ('older', 873),
#  ('ii', 871),
#  ('component', 870),
#  ('followed', 864),
#  ('status', 855),
#  ('interest', 854),
#  ('versus', 853),
#  ('scale', 853),
#  ('1999', 853),
#  ('department', 853),
#  ('process', 853),
#  ('conducted', 851),
#  ('suggest', 851),
#  ('medium', 851),
#  ("'", 851),
#  ('provide', 851),
#  ('growth', 851),
#  ('multiple', 849),
#  ('estimated', 847),
#  ('distribution', 846),
#  ('strategy', 845),
#  ('via', 845),
#  ('induced', 845),
#  ('contribution', 844),
#  ('el', 844),
#  ('improved', 843),
#  ('composition', 843),
#  ('length', 843),
#  ('tolerance', 842),
#  ('affect', 842),
#  ('0.5', 840),
#  ('conclusion', 840),
#  ('dynamic', 840),
#  ('accepted', 834),
#  ('stage', 830),
#  ('arterial', 829),
#  ('incremental', 828),
#  ('1998', 827),
#  ('surface', 827),
#  ('skin', 826),
#  ('exchange', 823),
#  ('known', 822),
#  ('analyzed', 822),
#  ('coronary', 820),
#  ('activation', 819),
#  ('air', 819),
#  ('positive', 818),
#  ('every', 818),
#  ('cancer', 817),
#  ('single', 816),
#  ('ventilation', 813),
#  ('school', 810),
#  ('upper', 809),
#  ('high-intensity', 808),
#  ('pain', 807),
#  ('exertion', 804),
#  ('information', 801),
#  ('i.e.', 799),
#  ('39', 799),
#  ('competition', 799),
#  ('specie', 797),
#  ('step', 796),
#  ('early', 796),
#  ('rpe', 794),
#  ('overall', 790),
#  ('atp', 790),
#  ('marker', 787),
#  ('70', 785),
#  ('better', 785),
#  ('complex', 784),
#  ('v˙', 784),
#  ('free', 783),
#  ('warm-up', 783),
#  ('sea', 780),
#  ('°c', 779),
#  ('form', 777),
#  ('investigation', 776),
#  ("''", 776),
#  ('furthermore', 775),
#  ('slope', 775),
#  ('mechanical', 775),
#  ('48', 772),
#  ('carbon', 772),
#  ('pathway', 770),
#  ('bias', 769),
#  ('primary', 767),
#  ('event', 766),
#  ('demand', 766),
#  ('international', 766),
#  ('throughout', 765),
#  ('38', 764),
#  ('indicated', 763),
#  ('1997', 760),
#  ('limitation', 760),
#  ('drug', 758),
#  ('ingestion', 757),
#  ('completed', 754),
#  ('cf', 754),
#  ('initial', 751),
#  ('site', 750),
#  ('version', 749),
#  ('altitude', 749),
#  ('soccer', 748),
#  ('open', 747),
#  ('absolute', 744),
#  ('anova', 744),
#  ('contrast', 742),
#  ('estimate', 742),
#  ('thermal', 742),
#  ('quality', 740),
#  ('variability', 739),
#  ('taken', 738),
#  ('nutr', 736),
#  ('elevated', 734),
#  ('fatty', 734),
#  ('brain', 733),
#  ('predicted', 731),
#  ('ass', 729),
#  ('collected', 727),
#  ('cognitive', 727),
#  ('reaction', 726),
#  ('lead', 725),
#  ('made', 725),
#  ('informed', 723),
#  ('prolonged', 723),
#  ('regulation', 722),
#  ('enzyme', 722),
#  ('efficiency', 722),
#  ('41', 721),
#  ('continuous', 719),
#  ('environment', 718),
#  ('receptor', 718),
#  ('myocardial', 717),
#  ('44', 715),
#  ('immediately', 715),
#  ('last', 713),
#  ('kinetics', 713),
#  ('//', 712),
#  ('mg', 711),
#  ('controlled', 710),
#  ('gait', 710),
#  ('rev', 707),
#  ('cause', 707),
#  ('relation', 707),
#  ('vo2peak', 707),
#  ('4.', 704),
#  ('linear', 704),
#  ('task', 702),
#  ('despite', 702),
#  ('therapy', 702),
#  ('sedentary', 700),
#  ('ventilatory', 696),
#  ('exercise-induced', 693),
#  ('independent', 692),
#  ('many', 691),
#  ('unit', 691),
#  ('received', 690),
#  ('43', 688),
#  ('adolescent', 688),
#  ('recent', 686),
#  ('indicate', 686),
#  ('movement', 686),
#  ('discussion', 684),
#  ('national', 683),
#  ('technique', 682),
#  ('life', 681),
#  ('metab', 680),
#  ('v.', 678),
#  ('reduce', 678),
#  ('severe', 678),
#  ('suggested', 677),
#  ('example', 677),
#  ('moreover', 676),
#  ('75', 676),
#  ('central', 676),
#  ('oxide', 675),
#  ('daily', 675),
#  ('general', 673),
#  ('long', 673),
#  ('combined', 669),
#  ('vascular', 667),
#  ('circulation', 667),
#  ('systolic', 662),
#  ('evaluation', 661),
#  ('no3', 661),
#  ('©', 660),
#  ('0.1', 659),
#  ('source', 657),
#  ('various', 656),
#  ('error', 655),
#  ('42', 654),
#  ('and/or', 654),
#  ('inhibition', 653),
#  ('approach', 648),
#  ('artery', 647),
#  ('selected', 647),
#  ('nature', 645),
#  ('systematic', 643),
#  ('ph', 643),
#  ('1996', 642),
#  ('short', 640),
#  ('involved', 639),
#  ('substrate', 639),
#  ('hypothesis', 636),
#  ('mitochondrion', 635),
#  ('copyright', 634),
#  ('race', 634),
#  ('center', 634),
#  ('consent', 631),
#  ('institute', 629),
#  ('muscular', 625),
#  ('negative', 625),
#  ('rehabilitation', 624),
#  ('release', 623),
#  ('curve', 623),
#  ('nm', 623),
#  ('sensitivity', 621),
#  ('diastolic', 617),
#  ('ed', 617),
#  ('ja', 617),
#  ('signal', 617),
#  ('cyclist', 616),
#  ('limited', 615),
#  ('final', 615),
#  ('dose', 614),
#  ('hypoxia', 614),
#  ('pre-', 613),
#  ('investigated', 612),
#  ('breathing', 612),
#  ('whole', 611),
#  ('workload', 611),
#  ('correlated', 609),
#  ('germany', 608),
#  ('presence', 608),
#  ('critical', 608),
#  ('red', 607),
#  ('purpose', 605),
#  ('cadence', 604),
#  ('able', 602),
#  ('hand', 601),
#  ('liver', 598),
#  ('o2max', 598),
#  ('expected', 598),
#  ('1994', 598),
#  ('perform', 597),
#  ('mortality', 597),
#  ('ﬁrst', 596),
#  ('examined', 596),
#  ('girl', 596),
#  ('highest', 594),
#  ('pa', 594),
#  ('m', 594),
#  ('longer', 593),
#  ('55', 593),
#  ('randomized', 592),
#  ('⫽', 592),
#  ('0.2', 589),
#  ('statistically', 589),
#  ('1995', 587),
#  ('47', 587),
#  ('46', 586),
#  ('em', 585),
#  ('i.e', 585),
#  ('people', 582),
#  ('org/', 581),
#  ('european', 581),
#  ('nitrate', 579),
#  ('que', 579),
#  ('antioxidant', 578),
#  ('assay', 578),
#  ('i.', 577),
#  ('core', 577),
#  ('college', 576),
#  ('limit', 576),
#  ('month', 576),
#  ('1985', 575),
#  ('1.5', 574),
#  ('benefit', 574),
#  ('hypertension', 574),
#  ('ca', 574),
#  ('knee', 573),
#  ('corresponding', 572),
#  ('future', 572),
#  ('md', 571),
#  ('consistent', 571),
#  ('pre', 570),
#  ('cochrane', 569),
#  ('guideline', 566),
#  ('literature', 566),
#  ('cho', 566),
#  ('jump', 566),
#  ('y.', 565),
#  ('co2', 564),
#  ('behavior', 562),
#  ('resulted', 561),
#  ('key', 559),
#  ('original', 558),
#  ('hospital', 557),
#  ('intermittent', 557),
#  ('stimulation', 557),
#  ('larger', 557),
#  ('target', 557),
#  ('pp', 556),
#  ('49', 555),
#  ('120', 553),
#  ('ﬁtness', 553),
#  ('peripheral', 553),
#  ('another', 552),
#  ('subsequent', 550),
#  ('revealed', 549),
#  ('approximately', 549),
#  ('5.', 548),
#  ('meal', 548),
#  ('cr', 546),
#  ('1991', 545),
#  ('damage', 544),
#  ('jr', 544),
#  ('boy', 543),
#  ('software', 542),
#  ('ﬂow', 540),
#  ('marathon', 539),
#  ('combination', 538),
#  ('treated', 537),
#  ('1.0', 536),
#  ('exp', 536),
#  ('post-exercise', 535),
#  ('re-', 535),
#  ('major', 535),
#  ('variance', 535),
#  ('optimal', 534),
#  ('1992', 533),
#  ('access', 532),
#  ('51', 532),
#  ('best', 532),
#  ('abstract', 531),
#  ('image', 530),
#  ('cold', 530),
#  ('maintain', 529),
#  ('region', 529),
#  ('nutrient', 527),
#  ('uk', 527),
#  ('relatively', 527),
#  ('com-', 527),
#  ('introduction', 525),
#  ('six', 525),
#  ('approved', 523),
#  ('suggests', 521),
#  ('limb', 519),
#  ('seen', 519),
#  ('field', 519),
#  ('impaired', 517),
#  ('jm', 517),
#  ('2022', 517),
#  ('der', 516),
#  ('vertical', 516),
#  ('evaluated', 515),
#  ('highly', 514),
#  ('resulting', 513),
#  ('200', 513),
#  ('1993', 513),
#  ('cardiopulmonary', 513),
#  ('signaling', 513),
#  ('still', 512),
#  ('supported', 512),
#  ('solution', 512),
#  ('obese', 511),
#  ('team', 511),
#  ('lack', 510),
#  ('added', 510),
#  ('juice', 509),
#  ('pro-', 508),
#  ('enhanced', 507),
#  ('need', 507),
#  ('rer', 507),
#  ('hypoxic', 506),
#  ('53', 504),
#  ('studied', 504),
#  ('indicates', 503),
#  ('dependent', 503),
#  ('public', 503),
#  ('basal', 503),
#  ('improves', 501),
#  ('directly', 501),
#  ('mp', 501),
#  ('deviation', 499),
#  ('phosphorylation', 496),
#  ('achieved', 496),
#  ('dysfunction', 495),
#  ('membrane', 494),
#  ('1990', 494),
#  ('five', 492),
#  ('equivalent', 490),
#  ('observation', 490),
#  ('hiit', 490),
#  ('student', 489),
#  ('respir', 489),
#  ('fraction', 489),
#  ('balance', 489),
#  ('depth', 489),
#  ('tested', 486),
#  ('cohort', 486),
#  ('z', 486),
#  ('decline', 485),
#  ('in-', 485),
#  ('spinal', 485),
#  ('complete', 484),
#  ('54', 483),
#  ('phys', 483),
#  ('contact', 483),
#  ('appropriate', 480),
#  ('wang', 480),
#  ('synthesis', 478),
#  ('onset', 478),
#  ('downloaded', 478),
#  ('jones', 477),
#  ('magnitude', 477),
#  ('defined', 476),
#  ('needed', 476),
#  ('transport', 475),
#  ('application', 474),
#  ('long-term', 474),
#  ('section', 474),
#  ('white', 474),
#  ('ro', 473),
#  ('1988', 473),
#  ('mode', 473),
#  ('fact', 472),
#  ('fiber', 472),
#  ('compression', 472),
#  ('much', 471),
#  ('52', 471),
#  ('committee', 470),
#  ('economy', 470),
#  ('mj', 470),
#  ...]

# %%
def test_word(df, indicator_col_name, text_col_name, test_word):
    test_words = []
    temp_df = df
    for idx, row in temp_df.iterrows():
        if test_word in row[text_col_name]:
            test_words.append('y')
        else:
            test_words.append('n')
    temp_df[test_word] = test_words
    ct = pd.crosstab(temp_df[indicator_col_name], temp_df[test_word], margins=True)
    return ct

# %%
test_word(gas_clf_df, indicator_col_name='Gas data', text_col_name='words', test_word='exercise')
# exercise seems like the next best word to add to the electronic search
# Out:
# exercise   n    y  All
# Gas data
# n         91  220  311
# y          5  288  293
# All       96  508  604

# %%
exercise = []
for idx, row in gas_clf_df.iterrows():
    if 'exercise' in row['words']:
        exercise.append('y')
    else:
        exercise.append('n')
gas_clf_df['exercise'] = exercise

# %%
df = gas_clf_df[(gas_clf_df['exercise'] == 'n') & (gas_clf_df['Gas data'] == 'y')]
df
# Out:
#                Article Eligible Eligibility note External ref Gas data  \
# 329  s40279-017-0811-2        e              NaN            n        y
# 364   fspor.2020.00044        e              NaN            n        y
# 377         jeb.024927        e              NaN            n        y
# 386          jeb.02782        e              NaN            n        y
# 567          sms.12514        e              NaN            n        y
#
#              txt_file_name                                              words  \
# 329  s40279-017-0811-2.txt  [sport, med, (, 2018, ), 48:1009–1019, http, :...
# 364   fspor.2020.00044.txt  [original, research, published, :, 28, april, ...
# 377         jeb.024927.txt  [corrigendum, control, function, arm, swing, h...
# 386          jeb.02782.txt  [2390, journal, experimental, biology, 210, ,,...
# 567          sms.12514.txt  [reduced, oxygen, cost, running, related, alig...
#
#      avg_word_len exercise
# 329      3.926697        n
# 364      5.034149        n
# 377      4.810747        n
# 386      4.966608        n
# 567      4.768570        n

# %%
word_len = []
for words in gas_clf_df['words']:
    char_len = []
    for word in words:
        char_len.append(len(word))
    word_len.append(char_len)

# %%
gas_clf_df['avg_word_len'] = list(map(np.mean, word_len))
gas_clf_df[gas_clf_df['avg_word_len'] < 3.5]
