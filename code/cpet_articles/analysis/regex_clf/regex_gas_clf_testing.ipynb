# %%
import pandas as pd
import re
import glob
from pathlib import Path
from tqdm.notebook import tqdm
from langdetect import detect

import numpy as np
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer
from nltk.probability import FreqDist
# import random
# import requests
# import pickle
# import time

# %%
txt_files = glob.glob('/Users/antonhesse/Desktop/Anton/Education/UMN/Lab and Research/HSPL/CPET_scoping_review/data/cpet_articles/full_texts/txts/*.txt')
gas_clf_df = pd.read_csv('/Users/antonhesse/Desktop/Anton/Education/UMN/Lab and Research/HSPL/CPET_scoping_review/data/cpet_articles/Manual text analysis - exer.csv')
gas_clf_df['txt_file_name'] = gas_clf_df.apply(lambda x: str(x['Article'] + '.txt'), axis=1)
# gas_clf_df = gas_clf_df[(gas_clf_df['Eligible'] == 'e') & (gas_clf_df['External ref'] == 'n')].reset_index(drop=True)

# %%
for idx, row in gas_clf_df.iterrows():
    if row['Eligible'] != 'e':
        row['Gas data'] = 'n'
    if (row['External ref'] == 'y') & (row['Gas data'] != 'y'):
        row['Gas data'] = 'n'

# %%
def process_file_one_string(file_name, file_list):
    txt_re = re.compile(file_name)
    fname = list(filter(txt_re.search, file_list))[0]
    
    # check file size to make sure the txt file actually has text
    file_size = 0
    while file_size == 0:
        file_size = Path(fname).stat().st_size
        if file_size != 0: # check if conversion to txt didn't work
            with open(fname, 'r') as f:
                text = f.read()
        else:
            print('Empty file, returning None')
            return None
    text_lower = text.lower()
    
    return text_lower

# %%
def tokenize_file(file_name, file_list, mode = 'lemm'):
    txt_re = re.compile(file_name)
    fname = list(filter(txt_re.search, file_list))[0]
    
    # check file size to make sure the txt file actually has text
    file_size = 0
    while file_size == 0:
        file_size = Path(fname).stat().st_size
        if file_size != 0: # check if conversion to txt didn't work
            with open(fname, 'r') as f:
                text = f.read()
        else:
            print('Empty file, returning None')
            return None
    text_lower = text.lower()
    tokens = word_tokenize(text_lower)
    stop_words = set(stopwords.words('english'))

    filtered_tokens = [t for t in tokens if t not in stop_words]
    
    if mode == 'lemm':
        lemmatizer = WordNetLemmatizer()
        lemmatized_words = [lemmatizer.lemmatize(t) for t in filtered_tokens]

        return lemmatized_words
    
    elif mode == 'stem':
        stemmer = PorterStemmer()
        stemmed_words = [stemmer.stem(t) for t in filtered_tokens]
    
        return stemmed_words

# %%
analyzed_txt_files = gas_clf_df['txt_file_name'].to_list()

# %%
token_word_lists = [tokenize_file(f, txt_files, mode='lemm') for f in tqdm(analyzed_txt_files)]
long_word_lists = [process_file_one_string(f, txt_files) for f in tqdm(analyzed_txt_files)]
# Out:
#   0%|          | 0/380 [00:00<?, ?it/s]
#   0%|          | 0/380 [00:00<?, ?it/s]

# %%
gas_clf_df['article_text'] = long_word_lists
gas_clf_df['tokens'] = token_word_lists
gas_clf_df['avg_word_len'] = gas_clf_df.apply(lambda x: np.mean(list(map(len, x['tokens']))), axis=1)
gas_clf_df = gas_clf_df[gas_clf_df['avg_word_len'] > 1.5].reset_index(drop=True) # removes articles with pdf to txt conversion issue

# %%
gas_clf_df['language'] = gas_clf_df.apply(lambda x: detect(x['article_text']), axis=1)
# gas_clf_df['language'].value_counts()

# %%
# filtering by enlglish or Welch lol
gas_clf_df = gas_clf_df[gas_clf_df['language'].isin(['en', 'cy'])].reset_index(drop=True)

# %%
def oxygen_uptake_re(text):
    o2_uptake_consupmtion_re = re.compile(r'oxygen.{0,5}(uptake|consumption)', re.DOTALL)
    vo2max_peak_re = re.compile(r'(v)?o2.{0,2}(max|peak)?', re.DOTALL)
    aerobic_re = re.compile(r'(?<!an)aerobic.{0,2}(power|capacity)', re.DOTALL)
    
    mo_list = [
        o2_uptake_re.search(text),
        vo2max_re.search(text),
        aerobic_power_re.search(text)]
    
    mentions_o2_uptake = any(mo is not None for mo in mo_list)
    
    return mentions_o2_uptake

def gas_collection_methods_re(text):
    bbb_re = re.compile(r'breath.{0,5}breath', re.DOTALL)
    douglas_bag_re = re.compile(r'douglas.{0,5}bag', re.DOTALL)
    mixing_chamber_re = re.compile(r'mixing.{0,5}chamber', re.DOTALL)
    
    mo_list = [bbb_re.search(text), douglas_bag_re.search(text), mixing_chamber_re.search(text)]
    
    gas_methods = any(mo is not None for mo in mo_list)
    
    return gas_methods

def vo2_units_re(text):
    vo2_rel_re = re.compile(r'ml([^a-zA-Z]*kg[^a-zA-Z]*min|[^a-zA-Z]*min[^a-zA-Z]*kg)')
    # mL_min_kg_re = re.compile(r'ml[^a-zA-Z]*min[^a-zA-Z]*kg')
    
    # L_mL_min = re.compile(r'(m)?l[^a-zA-Z]*min')

    mo_list = [vo2_rel_re.search(text)]
    
    vo2_units = any(mo is not None for mo in mo_list)
    
    return vo2_units

def estimated_vo2_re(text):
    est_o2_uptake_re = re.compile(r'''(
    (estimat|indirect|calculat).{0,30}oxygen.{0,2}(uptake|consumption)|
    oxygen.{0,2}(uptake|consumption).{0,30}(estimat|indirect|calculat)
    )''',
                                           re.DOTALL | re.VERBOSE)
    
    est_vo2_re = re.compile(r'''(
    (estimat|indirect|calculat).{0,30}(v)?o2.{0,2}(max|peak)|
    (v)?o2.{0,2}(max|peak).{0,30}(estimat|indirect|calculat)
    )''',
                            re.DOTALL | re.VERBOSE)
    
    est_vo2_units_re = re.compile(r'''(
    (estimat|indirect|calculat).{0,30}ml([^a-zA-Z]*kg[^a-zA-Z]*min|[^a-zA-Z]*min[^a-zA-Z]*kg)|
    ml([^a-zA-Z]*kg[^a-zA-Z]*min|[^a-zA-Z]*min[^a-zA-Z]*kg).{0,30}(estimat|indirect|calculat)
    )''',
                            re.DOTALL | re.VERBOSE)
    
    mo_list = [est_o2_uptake_re.search(text), est_vo2_re.search(text), est_vo2_units_re.search(text)]
    est_vo2 = any(mo is not None for mo in mo_list)
    
    return est_vo2
    # assessment of aerobic capacity

# %%
gas_clf_df['o2_uptake'] = gas_clf_df.apply(lambda x: oxygen_uptake_re(x['article_text']), axis=1)
gas_clf_df['vo2_units'] = gas_clf_df.apply(lambda x: vo2_units_re(x['article_text']), axis=1)
gas_clf_df['gas_collection_methods'] = gas_clf_df.apply(lambda x: gas_collection_methods_re(x['article_text']), axis=1)
gas_clf_df['estimated_vo2'] = gas_clf_df.apply(lambda x: estimated_vo2_re(x['article_text']), axis=1)

# %%
pd.crosstab(gas_clf_df['Gas data'], gas_clf_df['o2_uptake'])
# if there is NO reference to O2 uptake, we can for sure say it's a no
# Out:
# o2_uptake  False  True
# Gas data
# n             19   106
# y              0   233

# %%
pd.crosstab(gas_clf_df['Gas data'], gas_clf_df['estimated_vo2'])
# Out:
# estimated_vo2  False  True
# Gas data
# n                 95    30
# y                166    67

# %%
pd.crosstab(gas_clf_df['Gas data'], gas_clf_df['gas_collection_methods'])
# Out:
# gas_collection_methods  False  True
# Gas data
# n                         122     3
# y                         122   111

# %%
pd.crosstab(gas_clf_df['Gas data'], gas_clf_df['vo2_units'])
# Out:
# vo2_units  False  True
# Gas data
# n             92    33
# y             52   181

# %%
gas_clf_df[(gas_clf_df['estimated_vo2'] == True) & (gas_clf_df['Gas data'] == 'y')]
# Out:
#                      Article Eligible Eligibility note External ref Gas data  \
# 5             tad-2005-17207        e              NaN            n        y
# 8         s41746-021-00531-3        e              NaN            n        y
# 10                 srep42485        e              NaN            n        y
# 13   s1517-86922011000100008        e              NaN            n        y
# 24                sc.2017.34        e              NaN            n        y
# ..                       ...      ...              ...          ...      ...
# 317       ajpregu.00182.2018        e              NaN            n        y
# 324     02640414.2011.562232        e              NaN            n        y
# 332         fphys.2019.00365        e              NaN            n        y
# 337             thx.44.9.716        e              NaN            n        y
# 338            bjsm.25.4.191        e              NaN            n        y
#
#                    txt_file_name  \
# 5             tad-2005-17207.txt
# 8         s41746-021-00531-3.txt
# 10                 srep42485.txt
# 13   s1517-86922011000100008.txt
# 24                sc.2017.34.txt
# ..                           ...
# 317       ajpregu.00182.2018.txt
# 324     02640414.2011.562232.txt
# 332         fphys.2019.00365.txt
# 337             thx.44.9.716.txt
# 338            bjsm.25.4.191.txt
#
#                                           article_text  \
# 5    pdf hosted at the radboud repository of the ra...
# 8    www.nature.com/npjdigitalmed\n\nopen\n\narticl...
# 10   open\n\nreceived: 15 august 2016\naccepted: 11...
# 13   physiological and neuromuscular variables \nas...
# 24   spinal cord (2017) 55, 935–939\n& 2017 interna...
# ..                                                 ...
# 317  am j physiol regul integr comp physiol 315: r5...
# 324  effects of optimal pacing strategies for 400-,...
# 332  original research\npublished: 05 april 2019\nd...
# 337  thorax 1989;44:716-720\n\nadverse effect of ad...
# 338  br j sp med 1991; 25(4)\n\nbrief exercise indu...
#
#                                                 tokens  avg_word_len language  \
# 5    [pdf, hosted, radboud, repository, radboud, un...      4.708717       en
# 8    [www.nature.com/npjdigitalmed, open, article, ...      5.023291       en
# 10   [open, received, :, 15, august, 2016, accepted...      4.568605       en
# 13   [physiological, neuromuscular, variable, assoc...      4.896287       en
# 24   [spinal, cord, (, 2017, ), 55, ,, 935–939, &, ...      4.579608       en
# ..                                                 ...           ...      ...
# 317  [j, physiol, regul, integr, comp, physiol, 315...      4.960239       en
# 324  [effect, optimal, pacing, strategy, 400-, ,, 8...      4.443731       en
# 332  [original, research, published, :, 05, april, ...      4.758354       en
# 337  [thorax, 1989, ;, 44:716-720, adverse, effect,...      4.214140       en
# 338  [br, j, sp, med, 1991, ;, 25, (, 4, ), brief, ...      4.078345       en
#
#      o2_uptake  vo2_units  gas_collection_methods  estimated_vo2
# 5         True       True                   False           True
# 8         True       True                    True           True
# 10        True       True                    True           True
# 13        True       True                   False           True
# 24        True       True                    True           True
# ..         ...        ...                     ...            ...
# 317       True      False                   False           True
# 324       True       True                    True           True
# 332       True       True                    True           True
# 337       True      False                   False           True
# 338       True      False                   False           True
#
# [67 rows x 14 columns]

# %%
pd.crosstab(
    gas_clf_df['Gas data'],
    [
        gas_clf_df['gas_collection_methods'],
        gas_clf_df['vo2_units'],
        gas_clf_df['o2_uptake'],
    ]
)
# Out:
# gas_collection_methods False            True
# vo2_units              False      True False True
# o2_uptake              False True True  True True
# Gas data
# n                         15   77   30     0    3
# y                          0   34   88    18   93

# %%
gas_clf_df[
    (gas_clf_df['Gas data'] == 'n') & 
    (gas_clf_df['gas_collection_methods'] == False) &
    (gas_clf_df['vo2_units'] == True) &
    (gas_clf_df['o2_uptake'] == True)
]
# Out:
#                      Article Eligible Eligibility note External ref Gas data  \
# 26        s12887-022-03257-7        e              NaN            n        n
# 31         s00421-017-3677-y        i              NaN          NaN        n
# 40   s0066-782x2012005000092        e              NaN            n        n
# 83             pes.2018-0141        i        Not OP-RR          NaN        n
# 100     jsc.0b013e3181876ad0        e              NaN            n        n
# 120               nu10070815        e              NaN            n        n
# 184         bjsm.2008.046391        e              NaN            n        n
# 212     journal.pone.0118809        i        Non-human          NaN        n
# 217       s12931-020-01350-y        e              NaN            n        n
# 227        s12889-017-4237-4        e              NaN            n        n
# 238  japplphysiol.00051.2011        e              NaN            y        n
# 242            s004210050508        e              NaN            n        n
# 246      1875399x02114010051        e              NaN            n        n
# 256        s00421-011-2115-9        i        Not OP-RR          NaN        n
# 269     journal.pone.0045755        e              NaN            n        n
# 271   14651858.cd012678.pub2        i        Not OP-RR          NaN        n
# 277     jsc.0000000000001431        e              NaN            n        n
# 300               bf00236696        i        Not OP-RR          NaN        n
# 312          ajph.85.12.1702        e              NaN            n        n
# 314             jc.2010-2735        e              NaN            y        n
# 318           1741-7015-9-74        i        Not OP-RR          NaN        n
# 319               bf00422845        i        Not OP-RR          NaN        n
# 322               bf00417773        i        Not OP-RR          NaN        n
# 329           sj.ijo.0801637        i        Not OP-RR          NaN        n
# 342           sj.ijo.0802845        i        Not OP-RR          NaN        n
# 344           sj.ijo.0801037        i        Not OP-RR          NaN        n
# 351                jeb.02440        i        Non-human          NaN        n
# 354        s00421-006-0181-1        i        Not OP-RR          NaN        n
# 355     mss.0000000000001204        i        Not OP-RR          NaN        n
# 356  s0066-782x2002001200004        e              NaN            n        n
#
#                    txt_file_name  \
# 26        s12887-022-03257-7.txt
# 31         s00421-017-3677-y.txt
# 40   s0066-782x2012005000092.txt
# 83             pes.2018-0141.txt
# 100     jsc.0b013e3181876ad0.txt
# 120               nu10070815.txt
# 184         bjsm.2008.046391.txt
# 212     journal.pone.0118809.txt
# 217       s12931-020-01350-y.txt
# 227        s12889-017-4237-4.txt
# 238  japplphysiol.00051.2011.txt
# 242            s004210050508.txt
# 246      1875399x02114010051.txt
# 256        s00421-011-2115-9.txt
# 269     journal.pone.0045755.txt
# 271   14651858.cd012678.pub2.txt
# 277     jsc.0000000000001431.txt
# 300               bf00236696.txt
# 312          ajph.85.12.1702.txt
# 314             jc.2010-2735.txt
# 318           1741-7015-9-74.txt
# 319               bf00422845.txt
# 322               bf00417773.txt
# 329           sj.ijo.0801637.txt
# 342           sj.ijo.0802845.txt
# 344           sj.ijo.0801037.txt
# 351                jeb.02440.txt
# 354        s00421-006-0181-1.txt
# 355     mss.0000000000001204.txt
# 356  s0066-782x2002001200004.txt
#
#                                           article_text  \
# 26   eskandarifard et al. bmc pediatrics          (...
# 31   the metabolic costs of walking and running up ...
# 40   original article\n\naerobic training does not ...
# 83   pediatric exercise science, 2019, 31, 184-190\...
# 100  bampouras, theodoros and marrin, kelly (2009) ...
# 120  article\noptimal adherence to a mediterranean ...
# 184  original article\n\n1unit for preventive \nnut...
# 212  research article\n\nendurance training inhibit...
# 217  swinarew et al. respiratory research          ...
# 227  tikanmäki et al. bmc public health  (2017) 17:...
# 238  citation for published version:\nturner, je, b...
# 242  eur j appl physiol (1999) 79: 285 – 289\n\no r...
# 246  1875-399x/21\n\nsend orders for reprints to re...
# 256  the master triathlete\n\nromuald lepers\n\n14\...
# 269  roc generated thresholds for field-assessed ae...
# 271  \n\n\n\n\n\n\n\n\n\n\n\ncochrane\nlibrar...
# 277  see discussions, stats, and author profiles fo...
# 300  sports med (2015) 45 (suppl 1):s5–s12\ndoi 10....
# 312  cholesterol and degree of fat unsaturation\non...
# 314  o r i g i n a l\n\na r t i c l e\n\ne n d o c ...
# 318  kelley et al. bmc medicine 2011, 9:74\nhttp://...
# 319  chapter 2\nphysiology of alpine skiing\n\nsimo...
# 322  sports medicine (2021) 51:1855–1874 \nhttps://...
# 329  international journal of obesity (2007) 31, 17...
# 342  west et al. bmc pediatrics           (2019) 19...
# 344  sports medicine (2021) 51:1949–1966 \nhttps://...
# 351  3940\n\nthe journal of experimental biology 20...
# 354  grimmer et al. journal of neuroengineering and...
# 355   \n\n. . . published ahead of print \n \n \n \...
# 356  arq  bras  cardiol\n2002;  79:  239-44.\n\nori...
#
#                                                 tokens  avg_word_len language  \
# 26   [eskandarifard, et, al, ., bmc, pediatrics, (,...      4.564543       en
# 31   [metabolic, cost, walking, running, 30, degree...      4.747726       en
# 40   [original, article, aerobic, training, alter, ...      4.940076       en
# 83   [pediatric, exercise, science, ,, 2019, ,, 31,...      4.860014       en
# 100  [bampouras, ,, theodoros, marrin, ,, kelly, (,...      4.916015       en
# 120  [article, optimal, adherence, mediterranean, d...      4.444631       en
# 184  [original, article, 1unit, preventive, nutriti...      4.602708       en
# 212  [research, article, endurance, training, inhib...      4.905543       en
# 217  [swinarew, et, al, ., respiratory, research, (...      5.225770       en
# 227  [tikanmäki, et, al, ., bmc, public, health, (,...      4.792403       en
# 238  [citation, published, version, :, turner, ,, j...      4.874131       en
# 242  [eur, j, appl, physiol, (, 1999, ), 79, :, 285...      4.729606       en
# 246  [1875-399x/21, send, order, reprint, reprint, ...      4.997939       en
# 256  [master, triathlete, romuald, leper, 14, 14.1,...      4.346146       en
# 269  [roc, generated, threshold, field-assessed, ae...      5.017565       en
# 271  [, , , , , , cochrane, library, cochrane...      5.071043       en
# 277  [see, discussion, ,, stats, ,, author, profile...      4.673292       en
# 300  [sport, med, (, 2015, ), 45, (, suppl, 1, ), :...      5.081362       en
# 312  [cholesterol, degree, fat, unsaturation, plasm...      5.075802       en
# 314  [r, g, n, l, r, c, l, e, e, n, c, r, n, e, r, ...      4.296207       en
# 318  [kelley, et, al, ., bmc, medicine, 2011, ,, 9:...      4.710260       en
# 319  [chapter, 2, physiology, alpine, skiing, simon...      4.387849       en
# 322  [sport, medicine, (, 2021, ), 51:1855–1874, ht...      4.613955       en
# 329  [international, journal, obesity, (, 2007, ), ...      4.834490       en
# 342  [west, et, al, ., bmc, pediatrics, (, 2019, ),...      4.871017       en
# 344  [sport, medicine, (, 2021, ), 51:1949–1966, ht...      4.409335       en
# 351  [3940, journal, experimental, biology, 209, ,,...      4.784446       en
# 354  [grimmer, et, al, ., journal, neuroengineering...      4.421915       en
# 355  [., ., ., published, ahead, print, meta-analys...      4.594075       en
# 356  [arq, bra, cardiol, 2002, ;, 79, :, 239-44., o...      5.021489       en
#
#      o2_uptake  vo2_units  gas_collection_methods
# 26        True       True                   False
# 31        True       True                   False
# 40        True       True                   False
# 83        True       True                   False
# 100       True       True                   False
# 120       True       True                   False
# 184       True       True                   False
# 212       True       True                   False
# 217       True       True                   False
# 227       True       True                   False
# 238       True       True                   False
# 242       True       True                   False
# 246       True       True                   False
# 256       True       True                   False
# 269       True       True                   False
# 271       True       True                   False
# 277       True       True                   False
# 300       True       True                   False
# 312       True       True                   False
# 314       True       True                   False
# 318       True       True                   False
# 319       True       True                   False
# 322       True       True                   False
# 329       True       True                   False
# 342       True       True                   False
# 344       True       True                   False
# 351       True       True                   False
# 354       True       True                   False
# 355       True       True                   False
# 356       True       True                   False

# %%
token_list_n = gas_clf_df[
    (gas_clf_df['Gas data'] == 'n') & 
    (gas_clf_df['gas_collection_methods'] == False) &
    (gas_clf_df['vo2_units'] == False) &
    (gas_clf_df['o2_uptake'] == True)
]['tokens'].tolist()

token_list_y = gas_clf_df[
    (gas_clf_df['Gas data'] == 'y') & 
    (gas_clf_df['gas_collection_methods'] == False) &
    (gas_clf_df['vo2_units'] == False) &
    (gas_clf_df['o2_uptake'] == True)
]['tokens'].tolist()

# %%
fdist_n = FreqDist()
for tokens in tqdm(token_list_n):
    for word in tokens:
        fdist_n[word] += 1

fdist_y = FreqDist()
for tokens in tqdm(token_list_y):
    for word in tokens:
        fdist_y[word] += 1
# Out:
#   0%|          | 0/77 [00:00<?, ?it/s]
#   0%|          | 0/34 [00:00<?, ?it/s]

# %%
# fdist_n.most_common()[0:40]

# %% [markdown]
# Articles where they *estimated* physical fitness are going to be tricky

# %%
# fdist_y.most_common()[0:40]

# %% [markdown]
# ## Passes
# 1. If the article does NOT mention anything about oxygen uptake, it does NOT include gas data
# 2. If the articles DOES mention gas collection methods, it INCLUDES gas data
